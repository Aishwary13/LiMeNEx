# %%
import pandas as pd

# %%
targetGenedf = pd.read_excel('D:/Raylab/LiMeNEx/FetchData/data/FASN.xls')
targetGenedf.columns = targetGenedf.iloc[1]
targetGenedf = targetGenedf.iloc[2:]
# Out:
# c:\Users\Aishwary Sharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
targetGenedf.iloc[0]['IPAGS|BSM|Other AGS'].split('|')
# Out:
# ['GATA2', 'FOXA1']

# %%
finaldf = pd.DataFrame(columns=['Database','TF','TargetGene','Tissue','Experiment'])

# %%
mapping = pd.read_csv('D:/Raylab/LiMeNEx/FetchData/Physiologicalsystem.csv')

for i in range(0,len(targetGenedf)):

    experi = targetGenedf.iloc[i]['Experiment Name']
    tissue = targetGenedf.iloc[i]['Tissue']
    targetGene = targetGenedf.iloc[i]['Symbol']
    
    Tf = targetGenedf.iloc[i]['IPAGS|BSM|Other AGS'].split('|')
    
    mask = mapping['Types'] == tissue
    temp = mapping[mask]

    #handling Immune tissue case 
    Immunetissue = tissue.split(', ')[1] if ',' in tissue else tissue

    mask2 = mapping['Types'] == Immunetissue
    temp2 = mapping[mask2]

    if(len(temp2) != 0):
        tissue = Immunetissue
        temp = temp2

    if(len(temp) == 0):
        print("New Tissue Type Detected! -> ",tissue)
        print('----------------------')

        print('Type system:')
        system = input()

        print('Type Tissue:')
        newtissue = input()

        print('newtissueType')
        newtissuetype = input()

        new_row = {'Physiological System':system, 'Tissue':newtissue, 'Types':newtissuetype}
        mapping = pd.concat([mapping, pd.DataFrame([new_row])],ignore_index = True)

        mapping.to_csv("D:/Raylab/LiMeNEx/FetchData/Physiologicalsystem.csv",index=False)
    
    mask = mapping['Types'] == tissue
    temp = mapping[mask]

    for tf in Tf:
        # Check if the combination of TF and target gene already exists
        existing_row = finaldf[(finaldf['TF'] == tf) & (finaldf['TargetGene'] == targetGene)]
        
        if not existing_row.empty:
            # Append the new experiment to the existing row's Experiment column
            existing_index = existing_row.index[0]
            finaldf.at[existing_index, 'Experiment'] += f", {experi}"
        else:
            # Add new row if it doesn't exist
            new_row = {'Database': 'SPP', 'TF': tf, 'TargetGene': targetGene, 'Tissue': temp.iloc[0]['Tissue'], 'Experiment': experi}
            finaldf = pd.concat([finaldf, pd.DataFrame([new_row])], ignore_index=True)
# Out:
# New Tissue Type Detected! ->  epithelium, ZR-75-1 cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  lymphoid lineage, unspecified, MS1 cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  epithelium, Caco-2 cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  epithelium, 1° HMEC cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  lymphoid lineage, unspecified, MS1 cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  epithelium, HREs
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  epithelium, LNCaP-1F5 cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# New Tissue Type Detected! ->  duct, epithelium, PANC-1 cells
# ----------------------
# Type system:
# Type Tissue:
# newtissueType
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[84], line 55
#      52     finaldf.at[existing_index, 'Experiment'] += f", {experi}"
#      53 else:
#      54     # Add new row if it doesn't exist
# ---> 55     new_row = {'Database': 'SPP', 'TF': tf, 'TargetGene': targetGene, 'Tissue': temp.iloc[0]['Tissue'], 'Experiment': experi}
#      56     finaldf = pd.concat([finaldf, pd.DataFrame([new_row])], ignore_index=True)
#
# File c:\Users\Aishwary Sharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Aishwary Sharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Aishwary Sharma\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
finaldf
# Out:
#    Database       TF TargetGene             Tissue  \
# 0       SPP    GATA2       FASN           Prostate
# 1       SPP    FOXA1       FASN           Prostate
# 2       SPP     CTCF       FASN               Skin
# 3       SPP      DEX       FASN      Mammary Gland
# 4       SPP     E2F1       FASN           Prostate
# 5       SPP    CEBPB       FASN         Leukocytes
# 6       SPP      MYC       FASN              Bone
# 7       SPP    FOXM1       FASN      Mammary Gland
# 8       SPP    GABPA       FASN           Prostate
# 9       SPP      SP1       FASN         Stem cells
# 10      SPP     SPI1       FASN         Leukocytes
# 11      SPP      SP2       FASN         Leukocytes
# 12      SPP      MAX       FASN         Leukocytes
# 13      SPP   BICALU       FASN           Prostate
# 14      SPP     HES6       FASN           Prostate
# 15      SPP     PAX5       FASN         Leukocytes
# 16      SPP    GATA3       FASN      Mammary Gland
# 17      SPP    17BE2       FASN      Mammary Gland
# 18      SPP    RUNX1       FASN              HSPCs
# 19      SPP     REST       FASN             Colon
# 20      SPP   ZNF143       FASN         Leukocytes
# 21      SPP    GATA1       FASN  Erythroid lineage
# 22      SPP     TP73       FASN              Bone
# 23      SPP   SREBF2       FASN         Leukocytes
# 24      SPP   POU2F2       FASN         Leukocytes
# 25      SPP      TBP       FASN              Liver
# 26      SPP      MAZ       FASN              Liver
# 27      SPP   STAT5A       FASN         Leukocytes
# 28      SPP    CREB1       FASN           Prostate
# 29      SPP    IFNA1       FASN         Leukocytes
# 30      SPP    GTF2B       FASN            Uterus
# 31      SPP    R1881       FASN           Prostate
# 32      SPP     ATF1       FASN         Leukocytes
# 33      SPP    TCF12       FASN              Liver
# 34      SPP      SRF       FASN         Stem cells
# 35      SPP    STAT3       FASN         Leukocytes
# 36      SPP     USF1       FASN              Liver
# 37      SPP     TP63       FASN               Skin
# 38      SPP  BHLHE40       FASN         Leukocytes
# 39      SPP      MYB       FASN         Leukocytes
# 40      SPP      4HT       FASN      Mammary Gland
#
#                                            Experiment
# 0                        FOXA1 + FBS | GATA2 ChIP-Seq
# 1   FOXA1 + FBS | GATA2 ChIP-Seq, DEX | FOXA1 ChIP...
# 2   CTCF IP - NHDF cells, Rep 2 , CTCF IP - SK-N-S...
# 3   DEX | FOXA1 ChIP-Seq - Rep 1, DEX | FOXA1 ChIP...
# 4   E2F1 ChIP-Seq - Rep 1, HES6 OE + BICALU | E2F1...
# 5        CEBPB ChIP-Seq - K562, CEBPB IP - MCF7 cells
# 6   MYC IP, MYC IP, MYC IP, MYC IP | IFNA1 - K562 ...
# 7      FOXM1 IP - MCF7 cells, FOXM1 IP | THSP - DS008
# 8                          GABPA IP - Rep 1, GABPA IP
# 9              SP1 IP - H1 cells, SP1 IP - K562 cells
# 10  SPI1 IP - GM12878 cells, SPI1 IP - GM12878 cel...
# 11                                SP2 IP - K562 cells
# 12                             MAX IP - GM12878 cells
# 13           HES6 OE + BICALU | E2F1 ChIP-Seq - Rep 3
# 14  HES6 OE + BICALU | E2F1 ChIP-Seq - Rep 3, HES6...
# 15  PAX5 IP - GM12878 cells, Rep 2, PAX5 IP - GM12...
# 16      GATA3 IP - MCF-7 cells, GATA3 IP - T47D cells
# 17  FOXA1 IP | 17BE2 - MCF-7, 17BE2 | FOXA1 ChIP-S...
# 18                                           RUNX1 IP
# 19  REST IP - HCT116 cells, REST IP - PFSK-N-SH ce...
# 20                          ZNF143 IP - GM12878 cells
# 21                       GATA1 IP - PBDE cells, Rep 1
# 22                     TP73 IP - alpha isoform, Rep 2
# 23                          SREBF2 IP - GM12878 cells
# 24                          POU2F2 IP - GM12878 cells
# 25                               TBP IP - HepG2 cells
# 26                               MAZ IP - HepG2 cells
# 27                          STAT5A IP - GM12878 cells
# 28                             CREB1 ChIP-Seq - Rep 1
# 29                MYC IP | IFNA1 - K562 cells, 30 min
# 30                                   GTF2B IP - Rep 2
# 31                     R1881 | FOXA1 ChIP-Seq - Rep 1
# 32                               ATF1 IP - K562 cells
# 33                              TCF12 IP - MCF7 cells
# 34                                    SRF IP - Rep 4
# 35                                STAT3 IP - SU-DHL-6
# 36                              USF1 IP - HepG2 cells
# 37                                            TP63 IP
# 38                         BHLHE40 IP - GM12878 cells
# 39                                     MYB IP - MOLT3
# 40                        MYC IP | 4HT - MCF10A cells

# %%
targetGenedf
# Out:
# 1                          Experiment Name Species  \
# 2             FOXA1 + FBS | GATA2 ChIP-Seq   Human
# 3             CTCF IP - NHDF cells, Rep 2    Human
# 4             DEX | FOXA1 ChIP-Seq - Rep 1   Human
# 5                    E2F1 ChIP-Seq - Rep 1   Human
# 6                    CEBPB ChIP-Seq - K562   Human
# ..                                     ...     ...
# 700                                E2F1 IP   Human
# 701  SREBF1 IP | INS + 22RHC - HepG2 cells   Human
# 702        CTCF IP - GM12878 cells, Rep 2    Human
# 703        CTCF IP - GM19099 cells, Rep 1    Human
# 704                    MAZ IP - HeLa cells   Human
#
# 1                                            Tissue Symbol Binding Score  \
# 2                           epithelium, LNCaP cells   FASN           352
# 3                                  epidermis, NHDFs   FASN           198
# 4                         epithelium, ZR-75-1 cells   FASN           490
# 5                           epithelium, LNCaP cells   FASN           638
# 6     myeloid lineage, myeloblasts, CML, K562 cells   FASN           326
# ..                                              ...    ...           ...
# 700                epithelium, MDA-MB-231 LM2 cells   FASN           334
# 701                         epithelium, HepG2 cells   FASN          2329
# 702  lymphoid lineage, B lymphocytes, GM12878 cells   FASN           559
# 703  lymphoid lineage, B lymphocytes, GM19099 cells   FASN           505
# 704                  cervix, epithelial, HeLa cells   FASN           110
#
# 1   IPAGS|BSM|Other AGS
# 2           GATA2|FOXA1
# 3                  CTCF
# 4             FOXA1|DEX
# 5                  E2F1
# 6                 CEBPB
# ..                  ...
# 700                E2F1
# 701   SREBF1|22RHC; INS
# 702                CTCF
# 703                CTCF
# 704                 MAZ
#
# [703 rows x 6 columns]

# %%
str.split(', ')
# Out:
# ['myeloid lineage', 'myeloblasts', 'CML', 'K562 cells']
